# %% [markdown]
# # Learning Vector Quantization

# %% [markdown]
# Learning vector quantization (LVQ), é um algoritimo de classificação supervisionado baseado em prototipos.
#
# Uma entre muitas outras aplicações para o LVQ é suprir a limitação do kNN, onde se é necessário manter um grande banco de dados de exemplos de treinamento para fazer previsões.O algoritmo LVQ trata disso aprendendo com um subconjunto muito menor de padrões que melhor representam os dados de treinamento.
#
# Este relatorio objetiva avaliar os algoritimos LVQ1, LVQ2.1 e LVQ3 implementados. Para avaliar serão utilizados dois bancos de dados do repositorio Promise: http://promise.site.uottawa.ca/SERepository/datasets-page.html

# %%
#Bibliotecas utilizadas
import misc
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

#modulos implementados
from LVQ import lvq1
from LVQ import lvq2_1
from LVQ import lvq3

# %% [markdown]
# ### Introdução

# %% [markdown]
# Dado um conjunto inicial de prototipos, o LVQ ajusta os atributos dos
# protótipos, de forma a posicionar cada protótipo em um ponto que seja
# possível estabelecer uma função discriminante para as classes.
#
# **Os passos basicos para o ajuste dos prototipos são**
#
# Para cada padrão do conjunto de treinamento:
# - Obtenha o protótipo mais próximo do padrão.
# - Se forem da mesma classe, aproxime o protótipo.
# - Se forem de classes diferentes, afaste o protótipo.

# %%
#-------------Utilizando um dataset artificial com apenas dois features para ilustrar o funcionamento do LVQ.-------------------
dataset = misc.loadData('long1.arff')
dataset = np.asarray(dataset)

plt.scatter(dataset[:,0],dataset[:,1], c = dataset[:,2])
plt.title("2d Dataset", fontsize='large')
plt.show()

#---------------------------------------Escolha de um prototipo aleatório de cada classe----------------------------------------
prototypes = misc.getRandomPrototypes(dataset,1)

plt.scatter(dataset[:,0],dataset[:,1], c = dataset[:,2])
plt.title("Prototipos: azul e verde", fontsize='large')
plt.scatter(prototypes[:,0],prototypes[:,1], c = ['g','r'])
plt.show()

#-----------------------------Ajuste dos prototipos utilizado o lvq1 com 0.4 de taxa de aprendizado-----------------------------
prototypes = lvq1(prototypes,dataset,0.4)

plt.title("Prototipos: azul e verde(ajustados)", fontsize='large')
plt.scatter(dataset[:,0],dataset[:,1], c = dataset[:,2])
plt.scatter(prototypes[:,0],prototypes[:,1], c = ['g','r'])
plt.show()
# Out:
# Using dataset: long1.arff

# %% [markdown]
# ## *LVQ1*

# %% [markdown]
# ### Metodologia

# %% [markdown]
# O *LVQ1* é a implementação base do *LVQ*, o mesmo busca ajustar os protótipos afim de obter um posicionamento que seja capaz de discriminar corretamente as classes do conjunto de treinamento, o algoritimo faz isso iterando sobre o conjunto, e para cada instância verifica o protótipo mais próximo utilizando a tecnica *kNN*, caso sejam de mesma classe, uma correção é feita no protótipo buscando aproximar o mesmo da instância, caso contrario é feito o afastamento. Essa iteração é feita um numero *n* de vezes, dependendo do conjunto de treinamento. Uma taxa de aprendizado **α** é utilizada na correção dos protátipos afim de fazer ajustes finos, onde a mesma decresce a cara iteração.
#
# \begin{align}
# \alpha (i) = \alpha_{inicial} * \Bigl(1 - \frac{i}{i_{max}}\Bigr)
# \end{align}

# %% [markdown]
# ![lvq1.PNG](attachment:lvq1.PNG)

# %% [markdown]
# ### Resultados

# %%
print "------------------------------Verificacao LVQ1 com 5 prototipos por classe-----------------------------"
from sklearn.neighbors import KNeighborsClassifier
#----------------------------------------LVQ1 com dataset CM1 do repositorio promise--------------------------------------------
dataset = misc.loadData('cm1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 3 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,5)

    #-----------------------------Ajuste dos prototipos utilizado o lvq1 com alfa inicial = 0.4---------------------------------
    prototypes = lvq1(prototypes,trainset,0.4)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ 3-nn:" + repr(media2/10.0)

#----------------------------------------LVQ1 com dataset KC1 do repositorio promise--------------------------------------------

dataset = misc.loadData('kc1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 3 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,5)

    #-----------------------------Ajuste dos prototipos utilizado o lvq1 com alfa inicial = 0.4---------------------------------
    prototypes = lvq1(prototypes,trainset,0.3)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ 3-nn:" + repr(media2/10.0)
# Out:
# ------------------------------Verificacao LVQ1 com 5 prototipos por classe-----------------------------
# Using dataset: cm1.arff
# Acuracia media LVQ 1-nn:90.13333333333333
# Acuracia media LVQ 3-nn:78.53333333333333
# Using dataset: kc1.arff
# Acuracia media LVQ 1-nn:84.78672985781992
# Acuracia media LVQ 3-nn:72.95418641390205

# %%
print "------------------------------Verificacao LVQ1 com 10 prototipos por classe-----------------------------"
from sklearn.neighbors import KNeighborsClassifier
#----------------------------------------LVQ1 com dataset CM1 do repositorio promise--------------------------------------------
dataset = misc.loadData('cm1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 5 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,10)

    #-----------------------------Ajuste dos prototipos utilizado o lvq1 com alfa inicial = 0.4---------------------------------
    prototypes = lvq1(prototypes,trainset,0.4)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ 3-nn:" + repr(media2/10.0)

#----------------------------------------LVQ1 com dataset KC1 do repositorio promise--------------------------------------------
dataset = misc.loadData('KC1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 5 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,10)

    #-----------------------------Ajuste dos prototipos utilizado o lvq1 com alfa inicial = 0.4---------------------------------
    prototypes = lvq1(prototypes,trainset,1)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ 3-nn:" + repr(media2/10.0)
# Out:
# ------------------------------Verificacao LVQ1 com 10 prototipos por classe-----------------------------
# Using dataset: cm1.arff
# Acuracia media LVQ 1-nn:88.99999999999999
# Acuracia media LVQ 3-nn:81.6
# Using dataset: KC1.arff
# Acuracia media LVQ 1-nn:84.18641390205372
# Acuracia media LVQ 3-nn:69.33649289099526

# %% [markdown]
# ## *LVQ2.1*

# %% [markdown]
# ### Metodologia

# %% [markdown]
# O *LVQ2.1* é uma melhoria do *LVQ1* previamente apresentado, o mesmo busca ajustar os protótipos afim de obter um posicionamento que seja capaz de discriminar corretamente as classes do conjunto de treinamento, o algoritimo faz isso iterando sobre o conjunto e para cada instância verifica os dois protótipo mais próximo utilizando a tecnica *kNN*, caso os protótipos vizinhos sejam de classes diferentes uma correção é feita nos dois protótipos, uma correção de afastamento e outra de aproximação relativa a instância do conjunto de treinamento. Uma observação a ser feita é que esta correção só será realizada se a instância estiver dentro de uma janela de distância definida de seguinte maneira.
# \begin{align}
# min \frac{d_i}{d_j} \frac{d_j}{d_i} > S
# \end{align}
#
# \begin{align}
# onde
# \end{align}
#
# \begin{align}
# S = \frac{1-W}{1+W}
# \end{align}
#
# Onde os valos *di* e *dj* são as distâncias dos protótipos relativos a instância *x* e *w* é o tamanho da janela que deve ser escolhido de acordo com o problema
# ![LVQ2.1.PNG](attachment:LVQ2.1.PNG)

# %% [markdown]
# ## Resultados

# %%
print "------------------------------Verificacao LVQ2.1 com 5 prototipos por classe-----------------------------"
from sklearn.neighbors import KNeighborsClassifier
#----------------------------------------LVQ2.1 com dataset CM1 do repositorio promise------------------------------------------
dataset = misc.loadData('cm1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 3 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,5)

    #-------------------------Ajuste dos prototipos utilizado o lvq2.1 com alfa inicial = 0.4 e w=0.6-----------------------------
    prototypes = lvq2_1(prototypes,trainset,0.4,0.6)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ2.1 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ2.1 3-nn:" + repr(media2/10.0)

#----------------------------------------LVQ2.1 com dataset KC1 do repositorio promise--------------------------------------------

dataset = misc.loadData('kc1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 3 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,5)

    #-----------------------Ajuste dos prototipos utilizado o lvq2.1 com alfa inicial = 0.4 e w=0.6-----------------------------
    prototypes = lvq2_1(prototypes,trainset,0.4,0.6)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ2.1 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ2.1 3-nn:" + repr(media2/10.0)
# Out:
# ------------------------------Verificacao LVQ2.1 com 5 prototipos por classe-----------------------------
# Using dataset: cm1.arff
# Acuracia media LVQ2.1 1-nn:89.53333333333333
# Acuracia media LVQ2.1 3-nn:89.66666666666666
# Using dataset: kc1.arff
# Acuracia media LVQ2.1 1-nn:84.67614533965245
# Acuracia media LVQ2.1 3-nn:84.75513428120061

# %%
print "------------------------------Verificacao LVQ2.1 com 10 prototipos por classe-----------------------------"
from sklearn.neighbors import KNeighborsClassifier
#----------------------------------------LVQ2.1 com dataset CM1 do repositorio promise-----------------------------------------
dataset = misc.loadData('cm1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino-----------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 5 prototipos aleatório de cada classe-----------------------------------
    prototypes = misc.getRandomPrototypes(trainset,10)

    #-------------------------Ajuste dos prototipos utilizado o lvq2.1 com alfa inicial = 0.4 e w=0.6-----------------------------
    prototypes = lvq2_1(prototypes,trainset,0.4,0.6)

    #-------------------------------------------Separação instancia/classe-----------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn-----------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn-----------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ2.1 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ2.1 3-nn:" + repr(media2/10.0)

#----------------------------------------LVQ2.1 com dataset KC1 do repositorio promise------------------------------------------

dataset = misc.loadData('kc1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino-----------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 5 prototipos aleatório de cada classe-----------------------------------
    prototypes = misc.getRandomPrototypes(trainset,10)

    #-------------------------Ajuste dos prototipos utilizado o lvq1 com alfa inicial = 0.4 e w=0.6-----------------------------
    prototypes = lvq2_1(prototypes,trainset,0.4,0.6)

    #-------------------------------------------Separação instancia/classe-----------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn-----------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn-----------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ2.1 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ2.1 3-nn:" + repr(media2/10.0)
# Out:
# ------------------------------Verificacao LVQ2.1 com 10 prototipos por classe-----------------------------
# Using dataset: cm1.arff
# Acuracia media LVQ2.1 1-nn:89.33333333333333
# Acuracia media LVQ2.1 3-nn:89.39999999999999
# Using dataset: kc1.arff
# Acuracia media LVQ2.1 1-nn:84.67614533965244
# Acuracia media LVQ2.1 3-nn:84.67614533965245

# %% [markdown]
# ## *LVQ3*

# %% [markdown]
# # Metodologia

# %% [markdown]
# O LVQ 3 tenta evitar o overfitting do LVQ 2.1. Este atua mesmo quando o elemento já esta sendo corretamente classificado pelos prototipos mais proximos.
#
# • Ajusta os protótipos mesmo quando os dois mais próximos são da
# mesma classe que o padrão de treinamento (aproximando-os do padrão).
#
# • Introduz um fator de estabilizacão **ε**.
#
# ![lvq3.PNG](attachment:lvq3.PNG)

# %% [markdown]
# ## Resultados

# %%
print "------------------------------Verificacao LVQ3 com 5 prototipos por classe-----------------------------"
from sklearn.neighbors import KNeighborsClassifier
#----------------------------------------LVQ3 com dataset CM1 do repositorio promise--------------------------------------------
dataset = misc.loadData('cm1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 3 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,5)

    #---------------------Ajuste dos prototipos utilizado o lvq3 com alfa inicial = 0.4, w=0.6 e e=0.5--------------------------
    prototypes = lvq3(prototypes,trainset,0.4,0.6,0.5)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ3 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ3 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ3 3-nn:" + repr(media2/10.0)

#----------------------------------------LVQ2.1 com dataset KC1 do repositorio promise--------------------------------------------

dataset = misc.loadData('kc1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 3 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,5)

    #---------------------Ajuste dos prototipos utilizado o lvq3 com alfa inicial = 0.4, w=0.6 e e=0.5--------------------------
    prototypes = lvq3(prototypes,trainset,0.4,0.6,0.5)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ3 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ3 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ3 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ3 3-nn:" + repr(media2/10.0)
# Out:
# ------------------------------Verificacao LVQ3 com 5 prototipos por classe-----------------------------
# Using dataset: cm1.arff
# Acuracia media LVQ3 1-nn:89.26666666666667
# Acuracia media LVQ3 3-nn:89.4
# Using dataset: kc1.arff
# Acuracia media LVQ3 1-nn:84.47077409162719
# Acuracia media LVQ3 3-nn:84.565560821485

# %%
print "------------------------------Verificacao LVQ3 com 10 prototipos por classe-----------------------------"
from sklearn.neighbors import KNeighborsClassifier
#----------------------------------------LVQ3 com dataset CM1 do repositorio promise--------------------------------------------
dataset = misc.loadData('cm1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 3 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,10)

    #---------------------Ajuste dos prototipos utilizado o lvq3 com alfa inicial = 0.4, w=0.6 e e=0.5--------------------------
    prototypes = lvq3(prototypes,trainset,0.4,0.6,0.5)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ3 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ3 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ3 3-nn:" + repr(media2/10.0)

#----------------------------------------LVQ2.1 com dataset KC1 do repositorio promise--------------------------------------------

dataset = misc.loadData('kc1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #---------------------------------------Escolha de 3 prototipos aleatório de cada classe------------------------------------
    prototypes = misc.getRandomPrototypes(trainset,10)

    #---------------------Ajuste dos prototipos utilizado o lvq3 com alfa inicial = 0.4, w=0.6 e e=0.5--------------------------
    prototypes = lvq3(prototypes,trainset,0.4,0.6,0.5)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    prototypes_instances = prototypes[:,range(len(prototypes[0])-1)]
    prototypes_class = map(str,prototypes[:,-1])

    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(prototypes_instances , prototypes_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ3 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(prototypes_instances , prototypes_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ3 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media LVQ3 1-nn:" + repr(media1/10.0)
print "Acuracia media LVQ3 3-nn:" + repr(media2/10.0)
# Out:
# ------------------------------Verificacao LVQ3 com 10 prototipos por classe-----------------------------
# Using dataset: cm1.arff
# Acuracia media LVQ3 1-nn:89.93333333333332
# Acuracia media LVQ3 3-nn:90.73333333333332
# Using dataset: kc1.arff
# Acuracia media LVQ3 1-nn:84.97630331753552
# Acuracia media LVQ3 3-nn:85.07109004739337

# %% [markdown]
# ## kNN

# %% [markdown]
# ## Resultados

# %%
print "-----------------------------------------------Verificacao kNN---------------------------------------------"
from sklearn.neighbors import KNeighborsClassifier
#----------------------------------------kNN com dataset CM1 do repositorio promise--------------------------------------------
dataset = misc.loadData('cm1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    trainset_instances = trainset[:,range(len(trainset[0])-1)]
    trainset_class = trainset[:,-1]
    
    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(trainset_instances , trainset_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ3 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(trainset_instances , trainset_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media 1-nn:" + repr(media1/10.0)
print "Acuracia media 3-nn:" + repr(media2/10.0)

#----------------------------------------kNN com dataset KC1 do repositorio promise--------------------------------------------

dataset = misc.loadData('kc1.arff')
dataset = np.asarray(dataset)

media1 = 0
media2 = 0
for aux in range(10):
    #-------------------------------Particionando o dataset aleatoriamente em 30% teste 70% treino------------------------------
    trainset, testset = train_test_split(dataset, test_size=0.30)

    #-------------------------------------------Separação instancia/classe------------------------------------------------------
    trainset_instances = trainset[:,range(len(trainset[0])-1)]
    trainset_class = trainset[:,-1]
    
    testset_instances = testset[:,range(len(testset[0])-1)]
    testset_class = testset[:,-1]

    #-------------------------------------------Verificação de acuracia com 1-nn------------------------------------------------
    #treinamento
    knn = KNeighborsClassifier(n_neighbors=1)  
    knn.fit(trainset_instances , trainset_class)
    #score
    media1 += knn.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ3 1-nn: "+repr(knn.score(testset_instances,testset_class) * 100) + '%'

    #-------------------------------------------Verificação de acuracia com 3-nn------------------------------------------------

    #treinamento
    knn2 = KNeighborsClassifier(n_neighbors=3)  
    knn2.fit(trainset_instances , trainset_class)
    #score
    media2 += knn2.score(testset_instances,testset_class) * 100
    #print "Acuracia LVQ2.1 3-nn: "+repr(knn2.score(testset_instances,testset_class) * 100) + '%'

print "Acuracia media 1-nn:" + repr(media1/10.0)
print "Acuracia media 3-nn:" + repr(media2/10.0)
# Out:
# -----------------------------------------------Verificacao kNN---------------------------------------------
# Using dataset: cm1.arff
# Acuracia media 1-nn:83.2
# Acuracia media 3-nn:87.0
# Using dataset: kc1.arff
# Acuracia media 1-nn:82.52764612954186
# Acuracia media 3-nn:84.06003159557662

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Os valores apresentados demonstram que o LVQ3 se sai melhor quando se tem um número maior de prototípos, isso deve-se ao fato do mesmo efetuar a correção mesmo quando os mais próximos são de mesma classe, ocasionando assim, uma melhor distribuição dos protótipos e evitando o overfitting que ocorre no LVQ2.1. O qual se sai melhor que o LVQ1 também quando se tem um maior número de protótipos, a regra da janela evita o afastamento dos protótipos que estão muito distantes, para que os mesmos não sejam afastados da região que estão "cobrindo".

# %% [markdown]
# **Tabela - 5 prototipos por classe**
#
# |    | LVQ1 | LVQ2.1 | LVQ3 |
# |--------|--------|--------|------|
# |   CM1 1-nn | 90.1 %| 89.5 % | 89.3 %
# |   KC1 1-nn | 84.8 %| 84.6 % | 84.4 %
# |   CM1 3-nn | 79.0 %| 89.7 % | 89.4 %
# |   KC1 3-nn | 72.9 %| 84.7 % | 85.6 %
#
# **Tabela - 10 prototipos por classe**
#
# | This   | LVQ1 | LVQ2.1 | LVQ3 |
# |--------|--------|--------|------|
# |   CM1 1-nn |88.9 %| 89.3 % | 90.0 %
# |   KC1 1-nn | 84.2 %| 84.6 % | 85.0 %
# |   CM1 3-nn | 81.6 %| 89.4 % | 90.7 %
# |   KC1 3-nn | 69.3 %| 84.7 % | 85.0 %
#
# **Tabela - kNN**
#
# |    | kNN |
# |--------|--------|
# |   CM1 1-nn | 83.2 %|
# |   KC1 1-nn | 82.5 %|
# |   CM1 3-nn | 87.0 %|
# |   KC1 3-nn | 84.0 %|

# %%
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>
